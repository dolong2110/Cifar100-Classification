# %%
# !git clone https://github.com/dolong2110/Cifar100-Classification.git
# Out:
# Cloning into 'Cifar100-Classification'...
# remote: Enumerating objects: 522, done.
# remote: Counting objects: 100% (522/522), done.
# remote: Compressing objects: 100% (375/375), done.
# remote: Total 522 (delta 282), reused 359 (delta 140), pack-reused 0
# Receiving objects: 100% (522/522), 75.38 KiB | 2.90 MiB/s, done.
# Resolving deltas: 100% (282/282), done.

# %%
# %cd Cifar100-Classification/
# Out:
# /content/Cifar100-Classification

# %%
# !pip install -r requirements.txt

# %%
 import torch
 torch.cuda.empty_cache()

# %%
# !python3 train.py --model resnet9 --augmentation True
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch [0], last_lr: 0.00015, train_loss: 4.1041, val_loss: 3.9133, val_acc: 0.0935
# Epoch [1], last_lr: 0.00044, train_loss: 3.4667, val_loss: 3.4330, val_acc: 0.1828
# Epoch [2], last_lr: 0.00076, train_loss: 2.9989, val_loss: 3.2167, val_acc: 0.2037
# Epoch [3], last_lr: 0.00097, train_loss: 2.6159, val_loss: 2.6763, val_acc: 0.3187
# Epoch [4], last_lr: 0.00099, train_loss: 2.3086, val_loss: 2.2904, val_acc: 0.3897
# Epoch [5], last_lr: 0.00095, train_loss: 2.0607, val_loss: 2.5169, val_acc: 0.3683
# Epoch [6], last_lr: 0.00087, train_loss: 1.8825, val_loss: 1.9733, val_acc: 0.4655
# Epoch [7], last_lr: 0.00075, train_loss: 1.7027, val_loss: 1.8309, val_acc: 0.5072
# Epoch [8], last_lr: 0.00061, train_loss: 1.5506, val_loss: 1.6677, val_acc: 0.5384
# Epoch [9], last_lr: 0.00046, train_loss: 1.4132, val_loss: 1.6332, val_acc: 0.5536
# ...

# %%
history = torch.load('cifar100.th')

# %%
from plots import graph
graph.plot_accuracies(history)

# %%
graph.plot_losses(history)

# %%
graph.plot_lrs(history)
